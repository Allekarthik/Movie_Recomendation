# %%
import pandas as pd

# https://files.grouplens.org/datasets/movielens/ml-25m.zip
movies = pd.read_csv("telugu.csv")

# %%
movies.head()
# Out:
#                          Title  Rating  Year                     Genre  \
# 0      Sye Raa Narasimha Reddy     7.6  2019  Action, Adventure, Drama
# 1                        Evaru     8.3  2019    Crime, Drama, Thriller
# 2  Agent Sai Srinivasa Athreya     8.5  2019     Action, Comedy, Crime
# 3                   Rakshasudu     8.4  2019   Action, Crime, Thriller
# 4                       Khaidi     8.6  2019          Action, Thriller
#
#   Duration                                              Story Certificate  \
# 0  167 min  A historical action epic inspired by the life ...   Not Rated
# 1  118 min  Sub-inspector Vikram Vasudev is entrusted with...   Not Rated
# 2  148 min  An authentic humorous investigative thriller r...          UA
# 3  122 min  A sub-inspector sets out in pursuit of a myste...          UA
# 4  145 min  A drug bust, an injured cop and a convicted cr...          UA
#
#    Votes
# 0  5,222
# 1  2,083
# 2  3,501
# 3    692
# 4  5,257

# %%
import re

def clean_title(title):
    title = re.sub("[^a-zA-Z0-9 ]", "", title)
    return title

# %%
movies["clean_title"] = movies["Title"].apply(clean_title)

# %%
movies
# Out:
#                           Title  Rating  Year                     Genre  \
# 0       Sye Raa Narasimha Reddy     7.6  2019  Action, Adventure, Drama
# 1                         Evaru     8.3  2019    Crime, Drama, Thriller
# 2   Agent Sai Srinivasa Athreya     8.5  2019     Action, Comedy, Crime
# 3                    Rakshasudu     8.4  2019   Action, Crime, Thriller
# 4                        Khaidi     8.6  2019          Action, Thriller
# 5                  Chitralahari     7.1  2019                     Drama
# 6                        Jersey     8.6  2019              Drama, Sport
# 7                      Maharshi     7.3  2019             Action, Drama
# 8                     Mallesham     8.5  2019                 Biography
# 9                  George Reddy     7.3  2019                    Action
# 10                       Majili     7.2  2019            Drama, Romance
# 11             Brochevarevarura     8.0  2019                    Comedy
# 12        Raja Vaaru Rani Gaaru     8.5  2019                   Romance
# 13          Prati Roju Pandaage     6.4  2019             Drama, Family
# 14                        Bigil     7.1  2019      Action, Drama, Sport
# 15                        Mudra     8.0  2019          Action, Thriller
# 16               Mathu Vadalara     8.5  2019   Comedy, Crime, Thriller
# 17                   Kolaigaran     7.2  2019      Action, Crime, Drama
# 18      F2: Fun and Frustration     6.3  2019                    Comedy
# 19                  Gang Leader     7.6  2019            Action, Comedy
# 20          Sarvam Thaala Mayam     7.6  2019              Drama, Music
# 21                   Venky Mama     6.4  2019     Action, Comedy, Drama
# 22                     Rajdooth     6.9  2019                     Drama
# 23         Meeku Matrame Chepta     6.1  2019                    Comedy
# 24                Falaknuma Das     6.3  2019          Action, Thriller
# 25          Gaddalakonda Ganesh     6.9  2019          Action, Thriller
# 26    Ninu Veedani Needanu Nene     5.9  2019                    Comedy
#
#    Duration                                              Story Certificate  \
# 0   167 min  A historical action epic inspired by the life ...   Not Rated
# 1   118 min  Sub-inspector Vikram Vasudev is entrusted with...   Not Rated
# 2   148 min  An authentic humorous investigative thriller r...          UA
# 3   122 min  A sub-inspector sets out in pursuit of a myste...          UA
# 4   145 min  A drug bust, an injured cop and a convicted cr...          UA
# 5   131 min  Down on luck and depressed by constant failure...          UA
# 6   157 min  A failed cricketer decides to revive his crick...          UA
# 7   176 min  Rishi, a millionaire businessman, returns to h...   Not Rated
# 8   131 min  The life of Padma Shri winner Chintakindi Mall...           U
# 9   153 min  A biopic based on the life of a student leader...          UA
# 10  154 min  A former cricket player nursing his wounds of ...           U
# 11  138 min  This is the story of 'R3 batch' consisting of ...          UA
# 12  133 min  The story of Raju who falls in love with Rani ...           U
# 13  146 min  With only a few weeks left to live, an aging g...          UA
# 14  179 min  A former football player struggles to fulfill ...           U
# 15  108 min  An investigative journalist is arrested for ch...          UA
# 16  130 min  The movie shows the events that occur in the l...          UA
# 17  109 min  A man on a murder spree meets his match in a b...          UA
# 18  148 min  After Venky, Varun also gets married thinking ...          UA
# 19  155 min  Nani plays the gang leader of five women belon...          UA
# 20  131 min  A mridangam maker's son, who aspires to learn ...          UA
# 21  149 min  A story of nephew and a son which revolves aro...           U
# 22  130 min  A 25-year-old rouge's quest for an old Rajdoot...          UA
# 23  120 min  Rakesh, in an effort to woo his fiance, has pr...          UA
# 24  145 min  Set in the backdrop of the colonies of falaknu...           A
# 25  130 min  An aspiring filmmaker who wants to direct a re...          UA
# 26  123 min  A young man who gets mired in a dire situation...          UA
#
#     Votes                  clean_title
# 0   5,222      Sye Raa Narasimha Reddy
# 1   2,083                        Evaru
# 2   3,501  Agent Sai Srinivasa Athreya
# 3     692                   Rakshasudu
# 4   5,257                       Khaidi
# 5   1,230                 Chitralahari
# 6   4,428                       Jersey
# 7   4,571                     Maharshi
# 8     512                    Mallesham
# 9     367                 George Reddy
# 10  1,949                       Majili
# 11  1,410             Brochevarevarura
# 12    128        Raja Vaaru Rani Gaaru
# 13    271          Prati Roju Pandaage
# 14  8,246                        Bigil
# 15    217                        Mudra
# 16    317               Mathu Vadalara
# 17    909                   Kolaigaran
# 18  1,703       F2 Fun and Frustration
# 19  1,550                  Gang Leader
# 20    932          Sarvam Thaala Mayam
# 21    372                   Venky Mama
# 22     48                     Rajdooth
# 23    213         Meeku Matrame Chepta
# 24    437                Falaknuma Das
# 25    578          Gaddalakonda Ganesh
# 26    262    Ninu Veedani Needanu Nene

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
vectorizer = TfidfVectorizer(ngram_range=(1,2))

tfidf = vectorizer.fit_transform(movies["clean_title"])

# %%
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np

def search(title):
    title = clean_title(title)
    query_vec = vectorizer.transform([title])
    similarity = cosine_similarity(query_vec, tfidf).flatten()
    indices = np.argpartition(similarity, -5)[-5:]
    results = movies.iloc[indices].iloc[::-1]
    
    return results

# %%
import ipywidgets as widgets
from IPython.display import display

movie_input = widgets.Text(
    value='Toy Story',
    description='Movie Title:',
    disabled=False
)
movie_list = widgets.Output()

def on_type(data):
    with movie_list:
        movie_list.clear_output()
        title = data["new"]
        if len(title) > 5:
            display(search(title))

movie_input.observe(on_type, names='value')


display(movie_input, movie_list)
# Out:
# Text(value='Toy Story', description='Movie Title:')
# Output()
